# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x **2 )

# %%
fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_title('A single plot')
# Out:
# Text(0.5,1,'A single plot')

# %%
fix, axs = plt.subplots(2)
fix.suptitle('Vertically stacked subplots')
axs[0].plot(x,y)
axs[1].plot(x, -y)

# %% [markdown]
# If we are creating just a few Axes, it's handy to unpack them immediately to dedicated variables for each Axes. That way, we can use ```ax1``` instead of the more verbose `axs[0]`

# %%
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
ax1.plot(x,y)
ax2.plot(x, -y)

# %% [markdown]
# To obtain side-by-side subplots, pass paramerters 1, 2 for one row and two columns

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')asd
ax1.plot(x,y)
ax2.plot(x, -y)

# %% [markdown]
# ## Stacking subplots in two directions
#
# * When stacking in two directions, the returned `acs` is a 2D NumPy array.
# * If you have to set parameters for each subplot it's handy to iterate over all subplots in a 2D grid using for `ax` in `axs.flat`.

# %%
fig, axs = plt.subplots(2,2)
axs[0, 0].plot(x,y)
axs[0, 0].set_title('Axis [0, 0]')
axs[0,1].plot(x, y, 'tab:orange')
axs[0,1].set_title('Axis [0,1]')
axs[1,0].plot(y,x, 'tab:green')
axs[1,0].set_title('Axis [1,0]')
axs[1,1].plot(y, -x, 'tab:red')
axs[1,1].set_title('Axis [1,1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# This hides the x labels and tick labels for top plots and y ticks for right plots. Otherwise the labels in the middle get messed up.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# We can make this a bit better using tuple-unpacking to assign all subplots to dedicated variables:

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2)
fig.suptitle('Sharing x per column, y per row')
ax1.plot(x,y)
ax2.plot(x, y**2, 'tab:orange')
ax3.plot(x, -y, 'tab:green')
ax4.plot(x, -y**2, 'tab:red')

for ax in fig.get_axes():
    ax.label_outer

# %% [markdown]
# ### Testing for the project:
#
# * 4x4 graphic showing histograms of the original data in row one (4 graphs)
# *  histograms of sample averages for n=5, 30, and 100 in rows 2, 3 and 4 respectively
# * Overlay a theoretical normal curve for each of the 16 histograms using the mean and variance of the sample data for each case
# * Use the same X axis scale within each column!

# %%
#Creating 4x4 area in graphs

fig, axs = plt.subplots(4,4);
fig.suptitle('4 by 4 graphs')
for ax in axs.flat:
    ax.label_outer()
